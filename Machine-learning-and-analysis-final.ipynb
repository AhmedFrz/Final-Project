# %%
## Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.linear_model import LinearRegression, SGDRegressor
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn import svm
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error

# %%
## Read data from folders
df = pd.read_csv("cleaned_covid_data.csv")

# %%
## View a sample of the data
df.head()
# Out:
#   iso_code     location        date  total_cases  total_deaths  \
# 0      AFG  Afghanistan  12/31/2019          0.0           0.0
# 1      AFG  Afghanistan    1/1/2020          0.0           0.0
# 2      AFG  Afghanistan    1/2/2020          0.0           0.0
# 3      AFG  Afghanistan    1/3/2020          0.0           0.0
# 4      AFG  Afghanistan    1/4/2020          0.0           0.0
#
#    stringency_index  population  gdp_per_capita    HDI   TC   TD  STI  \
# 0               0.0    38928341        1803.987  0.498  0.0  0.0  0.0
# 1               0.0    38928341        1803.987  0.498  0.0  0.0  0.0
# 2               0.0    38928341        1803.987  0.498  0.0  0.0  0.0
# 3               0.0    38928341        1803.987  0.498  0.0  0.0  0.0
# 4               0.0    38928341        1803.987  0.498  0.0  0.0  0.0
#
#          POP    GDPCAP
# 0  17.477233  7.497754
# 1  17.477233  7.497754
# 2  17.477233  7.497754
# 3  17.477233  7.497754
# 4  17.477233  7.497754

# %%
## Check column data types,
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50418 entries, 0 to 50417
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   iso_code          50418 non-null  object
#  1   location          50418 non-null  object
#  2   date              50418 non-null  object
#  3   total_cases       50418 non-null  float64
#  4   total_deaths      50418 non-null  float64
#  5   stringency_index  50418 non-null  float64
#  6   population        50418 non-null  int64
#  7   gdp_per_capita    50418 non-null  float64
#  8   HDI               50418 non-null  float64
#  9   TC                50418 non-null  float64
#  10  TD                50418 non-null  float64
#  11  STI               50418 non-null  float64
#  12  POP               50418 non-null  float64
#  13  GDPCAP            50418 non-null  float64
# dtypes: float64(10), int64(1), object(3)
# memory usage: 5.4+ MB

# %%
# Data Analysis

# %%
## Which countries were most affected by Covid-19
## group by location getting max cases and fetching the top 25
most_cases_df = df.groupby(by=['location']).max('total_cases').nlargest(25, "total_cases")
most_cases_df
# Out:
#                 total_cases  total_deaths  stringency_index  population  \
# location
# United States     8154595.0      219674.0             72.69   331002647
# India             7550273.0      114610.0            100.00  1380004385
# Brazil            5235344.0      153905.0             81.02   212559409
# Russia            1399334.0       24187.0             87.04   145934460
# Argentina          989667.0       26267.0            100.00    45195777
# Colombia           959572.0       28970.0             90.74    50882884
# Spain              936560.0       33775.0             85.19    46754783
# France             897034.0       33477.0             87.96    65273512
# Peru               868675.0       33759.0             96.30    32971846
# Mexico             851227.0       86167.0             82.41   128932753
# United Kingdom     722409.0       43646.0             79.63    67886004
# South Africa       703793.0       18471.0             87.96    59308690
# Iran               530380.0       30375.0             63.89    83992953
# Chile              491760.0       13635.0             89.35    19116209
# Iraq               426634.0       10254.0             96.30    40222503
# Italy              414241.0       36543.0             93.52    60461828
# Bangladesh         388569.0        5660.0             93.52   164689383
# Germany            366299.0        9789.0             76.85    83783945
least_cases_df = df.groupby(by = ["location"]).max("total_cases").nsmallest(25, "total_cases")
least_cases_df
# Out:
#                                   total_cases  total_deaths  stringency_index  \
# location
# Hong Kong                                 0.0           0.0             66.67
# Anguilla                                  3.0           0.0             82.41
# Solomon Islands                           3.0           0.0              0.00
# Falkland Islands                         13.0           0.0             79.63
# Montserrat                               13.0           1.0             72.22
# Greenland                                16.0           0.0             77.78
# Saint Kitts and Nevis                    19.0           0.0              0.00
# Laos                                     23.0           0.0             96.30
# Vatican                                  26.0           0.0              0.00
# Grenada                                  27.0           0.0              0.00
# New Caledonia                            27.0           0.0              0.00
# Timor                                    29.0           0.0             77.78
# Fiji                                     32.0           2.0             88.89
# Dominica                                 33.0           0.0             79.63
# Saint Lucia                              33.0           0.0              0.00
# Saint Vincent and the Grenadines         67.0           0.0              0.00
# British Virgin Islands                   71.0           1.0             79.63
# Northern Mariana Islands                 86.0           2.0              0.00
# Antigua and Barbuda                     119.0           3.0              0.00
# Brunei                                  147.0           3.0             58.33
# Seychelles                              149.0           0.0             93.52
# Bonaire Sint Eustatius and Saba         150.0           2.0              0.00
# Bermuda                                 185.0           9.0             96.30
# Barbados                                222.0           7.0             88.89
# Liechtenstein                           224.0           1.0              0.00
#
#                                   population  gdp_per_capita    HDI        TC  \
# location
# Hong Kong                            7496988       56054.920  0.933  0.000000
# Anguilla                               15002           0.000  0.000  1.098612
# Solomon Islands                       686878        2205.923  0.546  1.098612
# Falkland Islands                        3483           0.000  0.000  2.564949
# Montserrat                              4999           0.000  0.000  2.564949
# Greenland                              56772           0.000  0.000  2.772589
# Saint Kitts and Nevis                  53192       24654.385  0.778  2.944439
# Laos                                 7275556        6397.360  0.601  3.135494
# Vatican                                  809           0.000  0.000  3.258097
# Grenada                               112519       13593.877  0.772  3.295837
# New Caledonia                         285491           0.000  0.000  3.295837
# Timor                                1318442        6570.102  0.625  3.367296
# Fiji                                  896444        8702.975  0.741  3.465736
# Dominica                               71991        9673.367  0.715  3.496508
# Saint Lucia                           183629       12951.839  0.747  3.496508
# Saint Vincent and the Grenadines      110947       10727.146  0.723  4.204693
# British Virgin Islands                 30237           0.000  0.000  4.262680
# Northern Mariana Islands               57557           0.000  0.000  4.454347
# Antigua and Barbuda                    97928       21490.943  0.780  4.779123
# Brunei                                437483       71809.251  0.853  4.990433
# Seychelles                             98340       26382.287  0.797  5.003946
# Bonaire Sint Eustatius and Saba        26221           0.000  0.000  5.010635
# Bermuda                                62273       50669.315  0.000  5.220356
# Barbados                              287371       16978.068  0.800  5.402677
# Liechtenstein                          38137           0.000  0.916  5.411646
#
#                                         TD       STI        POP     GDPCAP
# location
# Hong Kong                         0.000000  4.199755  15.830012  10.934087
# Anguilla                          0.000000  4.411707   9.615939   0.000000
# Solomon Islands                   0.000000  0.000000  13.439912   7.698901
# Falkland Islands                  0.000000  4.377391   8.155649   0.000000
# Montserrat                        0.000000  4.279717   8.516993   0.000000
# Greenland                         0.000000  4.353884  10.946799   0.000000
# Saint Kitts and Nevis             0.000000  0.000000  10.881663  10.112710
# Laos                              0.000000  4.567468  15.800031   8.763641
# Vatican                           0.000000  0.000000   6.695799   0.000000
# Grenada                           0.000000  0.000000  11.630877   9.517375
# New Caledonia                     0.000000  0.000000  12.561966   0.000000
# Timor                             0.000000  4.353884  14.091961   8.790285
# Fiji                              0.693147  4.487400  13.706191   9.071420
# Dominica                          0.000000  4.377391  11.184296   9.177132
# Saint Lucia                       0.000000  0.000000  12.120673   9.468993
# Saint Vincent and the Grenadines  0.000000  0.000000  11.616808   9.280533
# British Virgin Islands            0.000000  4.377391  10.316822   0.000000
# Northern Mariana Islands          0.693147  0.000000  10.960531   0.000000
# Antigua and Barbuda               1.098612  0.000000  11.491988   9.975387
# Brunei                            1.098612  4.066117  12.988793  11.181769
# Seychelles                        0.000000  4.538175  11.496186  10.180448
# Bonaire Sint Eustatius and Saba   0.693147  0.000000  10.174316   0.000000
# Bermuda                           2.197225  4.567468  11.039283  10.833076
# Barbados                          1.945910  4.487400  12.568529   9.739678
# Liechtenstein                     0.000000  0.000000  10.548940   0.000000

# %%
## What income group the countries affected fall into?
ax = most_cases_df["gdp_per_capita"].plot(label = "Most")
least_cases_df["gdp_per_capita"].plot(ax = ax, label = "Least")
plt.legend()
plt.xticks([])
# Out:
# ([], [])

# %%
ML Analysis

# %%
In this section we use as supervised ML algorithm, to check which are the most important features in this dataset. In this section we see how variables affect the number of cases. Therefore, we drop total_deaths variable due to its high correlation to the total_cases variable.

The most relevant features, are those that determine the outcome the most; those that influence the predictor variable total_cases the most.

# %%
df_type_max = df.groupby(by=['location']).sum('total_cases')
df_type_max.head()
# Out:
#              total_cases  total_deaths  stringency_index   population  \
# location
# Afghanistan    5126433.0      165875.0          13759.21  11444932254
# Albania        1071951.0       31056.0          14295.98    647505000
# Algeria        4893999.0      206429.0          16185.65  12892206642
# Andorra         223576.0        9850.0           9199.41     17461890
# Angola          304005.0       11820.0          15646.07   6967648816
#
#              gdp_per_capita      HDI           TC           TD         STI  \
# location
# Afghanistan      530372.178  146.412  2000.646094  1226.948181  896.603996
# Albania         2655771.975  176.625  1702.240756   929.368800  883.653354
# Algeria         4090668.666  221.676  2052.510847  1406.216387  939.379534
# Andorra               0.000  193.908  1465.828250   786.655112  787.230267
# Angola          1233732.940  123.172  1203.978763   590.138675  871.874556
#
#                      POP       GDPCAP
# location
# Afghanistan  5138.306531  2204.339821
# Albania      3346.320751  2109.632744
# Algeria      5173.314864  2804.947935
# Andorra      2543.629175     0.000000
# Angola       3669.286969  1837.821379

# %%
df_type_max.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 210 entries, Afghanistan to Zimbabwe
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   total_cases       210 non-null    float64
#  1   total_deaths      210 non-null    float64
#  2   stringency_index  210 non-null    float64
#  3   population        210 non-null    int64
#  4   gdp_per_capita    210 non-null    float64
#  5   HDI               210 non-null    float64
#  6   TC                210 non-null    float64
#  7   TD                210 non-null    float64
#  8   STI               210 non-null    float64
#  9   POP               210 non-null    float64
#  10  GDPCAP            210 non-null    float64
# dtypes: float64(10), int64(1)
# memory usage: 19.7+ KB

# %%
Preprocessing

# %%
We need to remove non-numeric variables (columns) from our dataset. We drop the following columns; iso_code, location and date.

# %%
# df_pre = df.drop(['iso_code', 'date'], axis=1)
df_pre = df_type_max.copy()
df_pre.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 210 entries, Afghanistan to Zimbabwe
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   total_cases       210 non-null    float64
#  1   total_deaths      210 non-null    float64
#  2   stringency_index  210 non-null    float64
#  3   population        210 non-null    int64
#  4   gdp_per_capita    210 non-null    float64
#  5   HDI               210 non-null    float64
#  6   TC                210 non-null    float64
#  7   TD                210 non-null    float64
#  8   STI               210 non-null    float64
#  9   POP               210 non-null    float64
#  10  GDPCAP            210 non-null    float64
# dtypes: float64(10), int64(1)
# memory usage: 19.7+ KB

# %%
y_data = df_pre['total_cases'].to_numpy()
y_data
# Out:
# array([5.12643300e+06, 1.07195100e+06, 4.89399900e+06, 2.23576000e+05,
#        3.04005000e+05, 6.14000000e+02, 1.26190000e+04, 4.71552340e+07,
#        5.47462900e+06, 2.15110000e+05, 3.01237700e+06, 4.90919700e+06,
#        4.23678200e+06, 2.37908000e+05, 6.54999500e+06, 3.52661780e+07,
#        2.49980000e+04, 1.05951860e+07, 1.51924680e+07, 1.06383000e+05,
#        2.45893000e+05, 2.88760000e+04, 2.28470000e+04, 1.18588380e+07,
#        5.08000000e+03, 2.20005700e+06, 2.05758000e+05, 4.25704517e+08,
#        4.60500000e+03, 3.01400000e+04, 1.89038000e+06, 2.31452000e+05,
#        4.97450000e+04, 3.95390000e+04, 2.47650200e+06, 2.09023740e+07,
#        4.63888000e+05, 3.31730000e+04, 5.93048000e+05, 1.54173000e+05,
#        5.12680340e+07, 2.16323190e+07, 6.05436820e+07, 5.24370000e+04,
#        4.73368000e+05, 4.63183500e+06, 2.13288300e+06, 1.31403100e+06,
#        5.81546000e+05, 1.97770000e+04, 2.36673000e+05, 5.21398000e+06,
#        1.27139100e+06, 3.03008800e+06, 7.81771000e+05, 3.97700000e+03,
#        1.06496460e+07, 1.44087570e+07, 1.24228450e+07, 2.57320600e+06,
#        5.57355000e+05, 4.00260000e+04, 4.45402000e+05, 4.87641700e+06,
#        5.68930000e+04, 2.46700000e+03, 4.74200000e+03, 1.45848400e+06,
#        5.00843350e+07, 9.53880000e+04, 1.03180300e+06, 2.29521000e+05,
#        4.31689000e+05, 4.24476780e+07, 4.90064900e+06, 4.53400000e+04,
